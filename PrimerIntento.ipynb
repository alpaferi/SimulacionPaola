# %% [markdown]
# # Aqui el primer texto en jupyter tranquilon
# c:
#
# :c
# link
#
# https://www.youtube.com/watch?v=eIo4AvtvSxc

# %% [markdown]
# ![image.png](attachment:image.png)
# c:

# %%
lista1 = ['tu vas bien', 'oui', 'ca ba', 32, 5.8]
#print(lista1)
#print(lista1+ ["oue", "merci"])
print(lista1 [2:-2])
# Out:
# ['ca ba']

# %%
tupla2 = ["hola, no puedes modificar"]
print (tupla2)
print (tupla2 + ['jeje'])
# Out:
# ['hola, no puedes modificar']
# ['hola, no puedes modificar', 'jeje']
